# %%
from scrapy import Spider
from scrapy.crawler import CrawlerProcess

import logging
import os

# %%
def try_remove(filename):
    try:
        os.remove(filename)
    except OSError:
        pass

# %%
class BookingComOpinions(Spider):
    name = 'BookingComOpinionsSpider'
    
    custom_settings = {
        'FEED_URI': '%(json_file)s', 
        'FEED_FORMAT': 'json',
        'DOWNLOAD_DELAY': 3,
        'LOG_LEVEL': logging.DEBUG,
        'EXTENSIONS': {
            'scrapy.extensions.closespider.CloseSpider': 1
        },
        'CLOSESPIDER_ITEMCOUNT': 10
    }
    
    def parse(self, response):
        hotels = response.css('div.sr_item')
        for hotel in hotels:
            hotel_name = hotel.css('span.sr-hotel__name::text').get().strip()
            for hotel_link in hotel.css('.hotel_name_link.url'):
                yield response.follow(hotel_link, self.parse_hotel, meta={'hotel': hotel_name})
        
        for link in response.css('a[data-page-next]'):
            yield response.follow(link)
            
    def parse_hotel(self, response):
        hotel_name = response.meta['hotel']
        for reviews_link in response.css('a.show_all_reviews_btn'):
            yield response.follow(reviews_link, self.parse_reviews, meta={'hotel': hotel_name})
        
    def parse_reviews(self, response):
        hotel_name = response.meta['hotel']
        items = response.css('li.review_item')
        for item in items:
            publish_date = item.css('meta[itemprop="datePublished"]'
                                    '::attr(content)').get('')
            reviewer = item.css('div.review_item_reviewer')
            rev_count = reviewer.css('div.review_item_user_review_count::text').get('')
            
            review = item.css('div.review_item_review')
            rating = review.css('meta[itemprop="ratingValue"]'
                                    '::attr(content)').get('')
            raw_tags = review.css('li.review_info_tag::text').getall()
            tags = list(filter(None, map(str.strip, raw_tags)))

            yield {
                'hotel': hotel_name,
                'publish_date': publish_date,
                'rev_count': rev_count,
                'rating': rating,
                'tags': tags
            }
            
                    
        for next_page in response.css('a#review_next_page_link'):
            yield response.follow(next_page, self.parse_reviews,
                                 meta = response.meta)

# %%
ENTRY_URL = 'https://www.booking.com/searchresults.pl.html?ss=Podstrana'
json_file = 'hotels.json'
try_remove(json_file)

# %%
process = CrawlerProcess()
process.crawl(BookingComOpinions, start_urls=[ENTRY_URL], json_file=json_file)
# Out:
# 2019-04-10 23:48:34 [scrapy.utils.log] INFO: Scrapy 1.5.2 started (bot: scrapybot)
# 2019-04-10 23:48:34 [scrapy.utils.log] INFO: Versions: lxml 4.3.1.0, libxml2 2.9.9, cssselect 1.0.3, parsel 1.5.1, w3lib 1.20.0, Twisted 18.9.0, Python 3.7.2 (default, Dec 29 2018, 06:19:36) - [GCC 7.3.0], pyOpenSSL 19.0.0 (OpenSSL 1.1.1b  26 Feb 2019), cryptography 2.6.1, Platform Linux-4.9.0-8-amd64-x86_64-with-debian-9.8
# 2019-04-10 23:48:34 [scrapy.crawler] INFO: Overridden settings: {'CLOSESPIDER_ITEMCOUNT': 10, 'DOWNLOAD_DELAY': 3, 'FEED_FORMAT': 'json', 'FEED_URI': '%(json_file)s', 'LOG_LEVEL': 10}
# 2019-04-10 23:48:34 [scrapy.extensions.telnet] INFO: Telnet Password: ef9d2a3651d06c75
# 2019-04-10 23:48:34 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats',
#  'scrapy.extensions.closespider.CloseSpider']
# 2019-04-10 23:48:34 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2019-04-10 23:48:34 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2019-04-10 23:48:34 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2019-04-10 23:48:34 [scrapy.core.engine] INFO: Spider opened
# 2019-04-10 23:48:34 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2019-04-10 23:48:34 [scrapy.extensions.telnet] DEBUG: Telnet console listening on 127.0.0.1:6023

# %%
process.start()
# Out:
# 2019-04-10 23:48:35 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.booking.com/searchresults.pl.html?ss=Podstrana> (referer: None)
# 2019-04-10 23:48:38 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.booking.com/hotel/hr/sanantoniopodstrana.pl.html> from <GET https://www.booking.com/hotel/hr/sanantoniopodstrana.pl.html?from=searchresults%0A#hotelTmpl>
# 2019-04-10 23:48:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.booking.com/searchresults.pl.html?dest_id=-92454&dest_type=city&ss=Podstrana&offset=15> (referer: https://www.booking.com/searchresults.pl.html?ss=Podstrana)
# 2019-04-10 23:48:45 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.booking.com/hotel/hr/apartments-johnny.pl.html> from <GET https://www.booking.com/hotel/hr/apartments-johnny.pl.html?from=searchresults%0A#hotelTmpl>
# 2019-04-10 23:48:47 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.booking.com/hotel/hr/villa-senator.pl.html> from <GET https://www.booking.com/hotel/hr/villa-senator.pl.html?from=searchresults%0A#hotelTmpl>
# 2019-04-10 23:48:51 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.booking.com/hotel/hr/apartments-9.pl.html> from <GET https://www.booking.com/hotel/hr/apartments-9.pl.html?from=searchresults%0A#hotelTmpl>
# 2019-04-10 23:48:54 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.booking.com/hotel/hr/beach-bozikovina.pl.html> from <GET https://www.booking.com/hotel/hr/beach-bozikovina.pl.html?from=searchresults%0A#hotelTmpl>
# 2019-04-10 23:48:58 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.booking.com/hotel/hr/apartman-jelic.pl.html> from <GET https://www.booking.com/hotel/hr/apartman-jelic.pl.html?from=searchresults%0A#hotelTmpl>
# 2019-04-10 23:49:02 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.booking.com/hotel/hr/apartments-diamond.pl.html> from <GET https://www.booking.com/hotel/hr/apartments-diamond.pl.html?from=searchresults%0A#hotelTmpl>
# 2019-04-10 23:49:06 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.booking.com/hotel/hr/apartmani-nera.pl.html> from <GET https://www.booking.com/hotel/hr/apartmani-nera.pl.html?from=searchresults%0A#hotelTmpl>
# 2019-04-10 23:49:09 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.booking.com/hotel/hr/hoteledensplit.pl.html> from <GET https://www.booking.com/hotel/hr/hoteledensplit.pl.html?from=searchresults%0A#hotelTmpl>
# 2019-04-10 23:49:14 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.booking.com/hotel/hr/pansion-pitomcia.pl.html> from <GET https://www.booking.com/hotel/hr/pansion-pitomcia.pl.html?from=searchresults%0A#hotelTmpl>
# 2019-04-10 23:49:15 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.booking.com/hotel/hr/apartment-sur-la-plage.pl.html> from <GET https://www.booking.com/hotel/hr/apartment-sur-la-plage.pl.html?from=searchresults%0A#hotelTmpl>
# 2019-04-10 23:49:19 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.booking.com/hotel/hr/apartment-andrina.pl.html> from <GET https://www.booking.com/hotel/hr/apartment-andrina.pl.html?from=searchresults%0A#hotelTmpl>
# 2019-04-10 23:49:23 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.booking.com/hotel/hr/split.pl.html> from <GET https://www.booking.com/hotel/hr/split.pl.html?from=searchresults%0A#hotelTmpl>
# 2019-04-10 23:49:26 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.booking.com/hotel/hr/le-meridien-lav-split.pl.html> from <GET https://www.booking.com/hotel/hr/le-meridien-lav-split.pl.html?from=searchresults%0A#hotelTmpl>
# 2019-04-10 23:49:30 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.booking.com/hotel/hr/apartment-brankica-podstrana.pl.html> from <GET https://www.booking.com/hotel/hr/apartment-brankica-podstrana.pl.html?from=searchresults%0A#hotelTmpl>
# 2019-04-10 23:49:34 [scrapy.extensions.logstats] INFO: Crawled 2 pages (at 2 pages/min), scraped 0 items (at 0 items/min)
# 2019-04-10 23:49:40 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.booking.com/hotel/hr/apartments-johnny.pl.html> (failed 1 times): No route to host: 101: Network is unreachable.
# 2019-04-10 23:49:43 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.booking.com/hotel/hr/apartment-mares.pl.html> from <GET https://www.booking.com/hotel/hr/apartment-mares.pl.html?from=searchresults%0A#hotelTmpl>
# 2019-04-10 23:49:46 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.booking.com/hotel/hr/villa-senator.pl.html> (referer: https://www.booking.com/searchresults.pl.html?ss=Podstrana)
# 2019-04-10 23:49:50 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.booking.com/hotel/hr/apartments-9.pl.html> (referer: https://www.booking.com/searchresults.pl.html?ss=Podstrana)
# 2019-04-10 23:49:53 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.booking.com/hotel/hr/beach-bozikovina.pl.html> (referer: https://www.booking.com/searchresults.pl.html?ss=Podstrana)
# 2019-04-10 23:49:57 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.booking.com/hotel/hr/apartman-jelic.pl.html> (referer: https://www.booking.com/searchresults.pl.html?ss=Podstrana)
# 2019-04-10 23:50:00 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.booking.com/hotel/hr/apartments-diamond.pl.html> (referer: https://www.booking.com/searchresults.pl.html?ss=Podstrana)
# 2019-04-10 23:50:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.booking.com/hotel/hr/apartmani-nera.pl.html> (referer: https://www.booking.com/searchresults.pl.html?ss=Podstrana)
# 2019-04-10 23:50:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.booking.com/hotel/hr/hoteledensplit.pl.html> (referer: https://www.booking.com/searchresults.pl.html?ss=Podstrana)
# 2019-04-10 23:50:08 [scrapy.dupefilters] DEBUG: Filtered duplicate request: <GET https://www.booking.com/hotel/hr/hoteledensplit.pl.html#blockdisplay4> - no more duplicates will be shown (see DUPEFILTER_DEBUG to show all duplicates)
# 2019-04-10 23:50:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.booking.com/hotel/hr/pansion-pitomcia.pl.html> (referer: https://www.booking.com/searchresults.pl.html?ss=Podstrana)
# 2019-04-10 23:50:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.booking.com/hotel/hr/apartment-sur-la-plage.pl.html> (referer: https://www.booking.com/searchresults.pl.html?ss=Podstrana)
# 2019-04-10 23:50:19 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.booking.com/hotel/hr/apartment-andrina.pl.html> (referer: https://www.booking.com/searchresults.pl.html?ss=Podstrana)
# 2019-04-10 23:50:24 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.booking.com/hotel/hr/split.pl.html> (referer: https://www.booking.com/searchresults.pl.html?ss=Podstrana)
# 2019-04-10 23:50:27 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.booking.com/hotel/hr/le-meridien-lav-split.pl.html> (referer: https://www.booking.com/searchresults.pl.html?ss=Podstrana)
# 2019-04-10 23:50:30 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.booking.com/hotel/hr/apartment-brankica-podstrana.pl.html> (referer: https://www.booking.com/searchresults.pl.html?ss=Podstrana)
# 2019-04-10 23:50:33 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.booking.com/hotel/hr/apartments-johnny.pl.html> (referer: https://www.booking.com/searchresults.pl.html?ss=Podstrana)
# 2019-04-10 23:50:34 [scrapy.extensions.logstats] INFO: Crawled 16 pages (at 14 pages/min), scraped 0 items (at 0 items/min)
# 2019-04-10 23:50:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.booking.com/hotel/hr/apartment-mares.pl.html> (referer: https://www.booking.com/searchresults.pl.html?dest_id=-92454&dest_type=city&ss=Podstrana&offset=15)
# 2019-04-10 23:50:39 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.booking.com/searchresults.pl.html?dest_id=-92454&dest_type=city&ss=Podstrana&offset=30> (referer: https://www.booking.com/searchresults.pl.html?dest_id=-92454&dest_type=city&ss=Podstrana&offset=15)
# 2019-04-10 23:50:42 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.booking.com/hotel/hr/apartments-mate-podstrana.pl.html> from <GET https://www.booking.com/hotel/hr/apartments-mate-podstrana.pl.html?from=searchresults%0A#hotelTmpl>
# 2019-04-10 23:50:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.booking.com/reviews/hr/hotel/apartments-9.pl.html> (referer: https://www.booking.com/hotel/hr/apartments-9.pl.html)
# 2019-04-10 23:50:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/hr/hotel/apartments-9.pl.html>
# {'hotel': 'Apartments 9', 'publish_date': '2018-08-31', 'rev_count': '\n3 opinie\n', 'rating': '8.8', 'tags': ['Wyjazd wakacyjny', 'Rodzina z małymi dziećmi', 'Apartament z widokiem na morze', '8 noclegów']}
# 2019-04-10 23:50:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/hr/hotel/apartments-9.pl.html>
# {'hotel': 'Apartments 9', 'publish_date': '2018-08-16', 'rev_count': '\n2 opinie\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'Rodzina z małymi dziećmi', 'Apartament z widokiem na morze', '7 noclegów']}
# 2019-04-10 23:50:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/hr/hotel/apartments-9.pl.html>
# {'hotel': 'Apartments 9', 'publish_date': '2018-08-11', 'rev_count': '\n1 opinia\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'Podróżujący ze znajomymi', 'Apartament dwupoziomowy', '7 noclegów', 'Wysłana przez urządzenie mobilne']}
# 2019-04-10 23:50:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/hr/hotel/apartments-9.pl.html>
# {'hotel': 'Apartments 9', 'publish_date': '2018-08-11', 'rev_count': '\n4 opinie\n', 'rating': '7.5', 'tags': ['Wyjazd wakacyjny', 'Podróżujący ze znajomymi', 'Apartament z widokiem na morze', '6 noclegów', 'Wysłana przez urządzenie mobilne']}
# 2019-04-10 23:50:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/hr/hotel/apartments-9.pl.html>
# {'hotel': 'Apartments 9', 'publish_date': '2018-06-12', 'rev_count': '\n16 opinii\n', 'rating': '2.5', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Apartament z widokiem na morze', '2 noclegi', 'Wysłana przez urządzenie mobilne']}
# 2019-04-10 23:50:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/hr/hotel/apartments-9.pl.html>
# {'hotel': 'Apartments 9', 'publish_date': '2018-07-22', 'rev_count': '\n1 opinia\n', 'rating': '8.8', 'tags': ['Wyjazd wakacyjny', 'Podróżujący w pojedynkę', 'Apartament dwupoziomowy', '10 noclegów']}
# 2019-04-10 23:50:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/hr/hotel/apartments-9.pl.html>
# {'hotel': 'Apartments 9', 'publish_date': '2017-07-19', 'rev_count': '\n9 opinii\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'Grupa', 'Apartament dwupoziomowy', '7 noclegów']}
# 2019-04-10 23:50:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.booking.com/reviews/hr/hotel/beach-bozikovina.pl.html> (referer: https://www.booking.com/hotel/hr/beach-bozikovina.pl.html)
# 2019-04-10 23:50:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/hr/hotel/beach-bozikovina.pl.html>
# {'hotel': 'Beach Hotel Bozikovina', 'publish_date': '2017-09-01', 'rev_count': '\n3 opinie\n', 'rating': '9.6', 'tags': ['Wyjazd wakacyjny', 'Rodzina z małymi dziećmi', 'Apartament typu Deluxe z widokiem na morze', '6 noclegów']}
# 2019-04-10 23:50:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/hr/hotel/beach-bozikovina.pl.html>
# {'hotel': 'Beach Hotel Bozikovina', 'publish_date': '2017-08-30', 'rev_count': '\n1 opinia\n', 'rating': '8.3', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój trzyosobowy', '1 nocleg']}
# 2019-04-10 23:50:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/hr/hotel/beach-bozikovina.pl.html>
# {'hotel': 'Beach Hotel Bozikovina', 'publish_date': '2017-05-08', 'rev_count': '\n1 opinia\n', 'rating': '9.6', 'tags': ['Wyjazd wakacyjny', 'Rodzina z małymi dziećmi', 'Pokój trzyosobowy', '4 noclegi']}
# 2019-04-10 23:50:49 [scrapy.core.engine] INFO: Closing spider (closespider_itemcount)
# 2019-04-10 23:50:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/hr/hotel/beach-bozikovina.pl.html>
# {'hotel': 'Beach Hotel Bozikovina', 'publish_date': '2016-05-27', 'rev_count': '\n11 opinii\n', 'rating': '9.6', 'tags': ['Wyjazd wakacyjny', 'Grupa']}
# 2019-04-10 23:50:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/hr/hotel/beach-bozikovina.pl.html>
# {'hotel': 'Beach Hotel Bozikovina', 'publish_date': '2015-06-21', 'rev_count': '\n1 opinia\n', 'rating': '8.3', 'tags': ['Wyjazd wakacyjny', 'Rodzina z małymi dziećmi']}
# 2019-04-10 23:50:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/hr/hotel/beach-bozikovina.pl.html>
# {'hotel': 'Beach Hotel Bozikovina', 'publish_date': '2016-05-10', 'rev_count': '\n3 opinie\n', 'rating': '9.2', 'tags': ['Grupa']}
# 2019-04-10 23:50:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/hr/hotel/beach-bozikovina.pl.html>
# {'hotel': 'Beach Hotel Bozikovina', 'publish_date': '2015-06-02', 'rev_count': '\n7 opinii\n', 'rating': '8.3', 'tags': ['Wyjazd wakacyjny', 'Grupa']}
# 2019-04-10 23:50:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/hr/hotel/beach-bozikovina.pl.html>
# {'hotel': 'Beach Hotel Bozikovina', 'publish_date': '2015-05-01', 'rev_count': '\n13 opinii\n', 'rating': '9.6', 'tags': ['Wyjazd wakacyjny', 'W parze']}
# 2019-04-10 23:50:53 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.booking.com/hotel/hr/villa-maris-podstrana.pl.html> from <GET https://www.booking.com/hotel/hr/villa-maris-podstrana.pl.html?from=searchresults%0A#hotelTmpl>
# 2019-04-10 23:50:57 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.booking.com/reviews/hr/hotel/apartments-diamond.pl.html> (referer: https://www.booking.com/hotel/hr/apartments-diamond.pl.html)
# 2019-04-10 23:50:57 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/hr/hotel/apartments-diamond.pl.html>
# {'hotel': 'Apartments Diamond', 'publish_date': '2018-08-17', 'rev_count': '\n2 opinie\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'Rodzina z małymi dziećmi', 'Apartament z 1 sypialnią', '4 noclegi']}
# 2019-04-10 23:50:57 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/hr/hotel/apartments-diamond.pl.html>
# {'hotel': 'Apartments Diamond', 'publish_date': '2018-07-17', 'rev_count': '\n3 opinie\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'Rodzina z małymi dziećmi', 'Apartament z 1 sypialnią', '2 noclegi', 'Wysłana przez urządzenie mobilne']}
# 2019-04-10 23:50:57 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/hr/hotel/apartments-diamond.pl.html>
# {'hotel': 'Apartments Diamond', 'publish_date': '2018-07-05', 'rev_count': '\n4 opinie\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'Rodzina z małymi dziećmi', 'Apartament z 1 sypialnią', '9 noclegów', 'Wysłana przez urządzenie mobilne']}
# 2019-04-10 23:50:57 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/hr/hotel/apartments-diamond.pl.html>
# {'hotel': 'Apartments Diamond', 'publish_date': '2017-06-18', 'rev_count': '\n14 opinii\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'Podróżujący w pojedynkę', 'Apartament z 1 sypialnią', '6 noclegów']}
# 2019-04-10 23:50:57 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/hr/hotel/apartments-diamond.pl.html>
# {'hotel': 'Apartments Diamond', 'publish_date': '2015-09-25', 'rev_count': '\n1 opinia\n', 'rating': '9.6', 'tags': ['Wyjazd wakacyjny', 'Rodzina z małymi dziećmi']}
# 2019-04-10 23:51:01 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.booking.com/reviews/hr/hotel/apartmani-nera.pl.html> (referer: https://www.booking.com/hotel/hr/apartmani-nera.pl.html)
# 2019-04-10 23:51:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/hr/hotel/apartmani-nera.pl.html>
# {'hotel': 'Apartments Nera', 'publish_date': '2018-08-23', 'rev_count': '\n9 opinii\n', 'rating': '9.6', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Studio z balkonem i widokiem na morze', '6 noclegów']}
# 2019-04-10 23:51:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/hr/hotel/apartmani-nera.pl.html>
# {'hotel': 'Apartments Nera', 'publish_date': '2018-06-09', 'rev_count': '\n5 opinii\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Studio', '4 noclegi']}
# 2019-04-10 23:51:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/hr/hotel/apartmani-nera.pl.html>
# {'hotel': 'Apartments Nera', 'publish_date': '2018-07-17', 'rev_count': '\n38 opinii\n', 'rating': '10', 'tags': ['Rodzina z małymi dziećmi', '2 pokoje', '7 noclegów', 'Wysłana przez urządzenie mobilne']}
# 2019-04-10 23:51:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/hr/hotel/apartmani-nera.pl.html>
# {'hotel': 'Apartments Nera', 'publish_date': '2017-09-21', 'rev_count': '\n5 opinii\n', 'rating': '9.2', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Studio z balkonem i widokiem na morze', '13 noclegów']}
# 2019-04-10 23:51:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/hr/hotel/apartmani-nera.pl.html>
# {'hotel': 'Apartments Nera', 'publish_date': '2017-08-31', 'rev_count': '\n3 opinie\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Apartament z 2 sypialniami i balkonem oraz widokiem na morze', '6 noclegów']}
# 2019-04-10 23:51:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/hr/hotel/apartmani-nera.pl.html>
# {'hotel': 'Apartments Nera', 'publish_date': '2015-09-12', 'rev_count': '\n3 opinie\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'W parze']}
# 2019-04-10 23:51:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/hr/hotel/apartmani-nera.pl.html>
# {'hotel': 'Apartments Nera', 'publish_date': '2015-08-25', 'rev_count': '\n7 opinii\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'Rodzina z małymi dziećmi']}
# 2019-04-10 23:51:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/hr/hotel/apartmani-nera.pl.html>
# {'hotel': 'Apartments Nera', 'publish_date': '2015-08-17', 'rev_count': '\n1 opinia\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'W parze']}
# 2019-04-10 23:51:05 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.booking.com/hotel/hr/vlasic.pl.html> from <GET https://www.booking.com/hotel/hr/vlasic.pl.html?from=searchresults%0A#hotelTmpl>
# 2019-04-10 23:51:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.booking.com/reviews/hr/hotel/pansion-pitomcia.pl.html> (referer: https://www.booking.com/hotel/hr/pansion-pitomcia.pl.html)
# 2019-04-10 23:51:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/hr/hotel/pansion-pitomcia.pl.html>
# {'hotel': 'Villa Pitomcia', 'publish_date': '2018-05-07', 'rev_count': '\n22 opinie\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój Dwuosobowy z balkonem i widokiem na morze', '5 noclegów']}
# 2019-04-10 23:51:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/hr/hotel/pansion-pitomcia.pl.html>
# {'hotel': 'Villa Pitomcia', 'publish_date': '2017-09-11', 'rev_count': '\n49 opinii\n', 'rating': '8.8', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój Dwuosobowy z balkonem i widokiem na morze', '2 noclegi']}
# 2019-04-10 23:51:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/hr/hotel/pansion-pitomcia.pl.html>
# {'hotel': 'Villa Pitomcia', 'publish_date': '2017-08-07', 'rev_count': '\n8 opinii\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój Dwuosobowy z balkonem i widokiem na morze', '3 noclegi']}
# 2019-04-10 23:51:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/hr/hotel/pansion-pitomcia.pl.html>
# {'hotel': 'Villa Pitomcia', 'publish_date': '2017-06-17', 'rev_count': '\n20 opinii\n', 'rating': '7.9', 'tags': ['Wyjazd wakacyjny', 'Grupa', 'Pokój Dwuosobowy z balkonem i widokiem na morze', '9 noclegów']}
# 2019-04-10 23:51:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/hr/hotel/pansion-pitomcia.pl.html>
# {'hotel': 'Villa Pitomcia', 'publish_date': '2018-08-25', 'rev_count': '\n4 opinie\n', 'rating': '8.8', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój Dwuosobowy z balkonem i widokiem na morze', '6 noclegów']}
# 2019-04-10 23:51:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/hr/hotel/pansion-pitomcia.pl.html>
# {'hotel': 'Villa Pitomcia', 'publish_date': '2018-06-12', 'rev_count': '\n7 opinii\n', 'rating': '9.2', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój dwuosobowy z tarasem i widokiem na morze.', '2 noclegi']}
# 2019-04-10 23:51:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/hr/hotel/pansion-pitomcia.pl.html>
# {'hotel': 'Villa Pitomcia', 'publish_date': '2017-07-02', 'rev_count': '\n5 opinii\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój dwuosobowy z tarasem i widokiem na morze.', '3 noclegi', 'Wysłana przez urządzenie mobilne']}
# 2019-04-10 23:51:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/hr/hotel/pansion-pitomcia.pl.html>
# {'hotel': 'Villa Pitomcia', 'publish_date': '2017-06-01', 'rev_count': '\n12 opinii\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój dwuosobowy z tarasem i widokiem na morze.', '4 noclegi', 'Wysłana przez urządzenie mobilne']}
# 2019-04-10 23:51:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/hr/hotel/pansion-pitomcia.pl.html>
# {'hotel': 'Villa Pitomcia', 'publish_date': '2015-10-13', 'rev_count': '\n22 opinie\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'Grupa']}
# 2019-04-10 23:51:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/hr/hotel/pansion-pitomcia.pl.html>
# {'hotel': 'Villa Pitomcia', 'publish_date': '2015-08-03', 'rev_count': '\n7 opinii\n', 'rating': '6.7', 'tags': ['Wyjazd wakacyjny', 'Grupa']}
# 2019-04-10 23:51:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/hr/hotel/pansion-pitomcia.pl.html>
# {'hotel': 'Villa Pitomcia', 'publish_date': '2015-10-04', 'rev_count': '\n2 opinie\n', 'rating': '8.3', 'tags': ['Wyjazd wakacyjny', 'W parze']}
# 2019-04-10 23:51:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/hr/hotel/pansion-pitomcia.pl.html>
# {'hotel': 'Villa Pitomcia', 'publish_date': '2015-07-04', 'rev_count': '\n22 opinie\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'W parze']}
# 2019-04-10 23:51:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/hr/hotel/pansion-pitomcia.pl.html>
# {'hotel': 'Villa Pitomcia', 'publish_date': '2015-06-16', 'rev_count': '\n18 opinii\n', 'rating': '7.9', 'tags': ['Wyjazd wakacyjny', 'W parze']}
# 2019-04-10 23:51:13 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.booking.com/hotel/hr/villa-lenka-apartments.pl.html> from <GET https://www.booking.com/hotel/hr/villa-lenka-apartments.pl.html?from=searchresults%0A#hotelTmpl>
# 2019-04-10 23:51:17 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.booking.com/hotel/hr/apartments-goro.pl.html> from <GET https://www.booking.com/hotel/hr/apartments-goro.pl.html?from=searchresults%0A#hotelTmpl>
# 2019-04-10 23:51:21 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.booking.com/reviews/hr/hotel/split.pl.html> (referer: https://www.booking.com/hotel/hr/split.pl.html)
# 2019-04-10 23:51:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/hr/hotel/split.pl.html>
# {'hotel': 'Hotel Split', 'publish_date': '2018-05-15', 'rev_count': '\n1 opinia\n', 'rating': '8.8', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój Dwuosobowy typu Deluxe z widokiem na morze i tarasem', '4 noclegi']}
# 2019-04-10 23:51:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/hr/hotel/split.pl.html>
# {'hotel': 'Hotel Split', 'publish_date': '2017-08-06', 'rev_count': '\n9 opinii\n', 'rating': '5.4', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój dwuosobowy typu Superior z 1 lub 2 łóżkami i widokiem na morze i balkonem', '7 noclegów']}
# 2019-04-10 23:51:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/hr/hotel/split.pl.html>
# {'hotel': 'Hotel Split', 'publish_date': '2017-06-12', 'rev_count': '\n50 opinii\n', 'rating': '5.8', 'tags': ['Wyjazd służbowy', 'Grupa', 'Pokój dwuosobowy typu Superior z 1 lub 2 łóżkami i widokiem na morze i balkonem', '2 noclegi']}
# 2019-04-10 23:51:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/hr/hotel/split.pl.html>
# {'hotel': 'Hotel Split', 'publish_date': '2017-10-09', 'rev_count': '\n3 opinie\n', 'rating': '9.5', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój Dwuosobowy typu Deluxe z widokiem na morze i tarasem', '5 noclegów']}
# 2019-04-10 23:51:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/hr/hotel/split.pl.html>
# {'hotel': 'Hotel Split', 'publish_date': '2017-05-08', 'rev_count': '\n32 opinie\n', 'rating': '8.8', 'tags': ['Wyjazd wakacyjny', 'Rodzina z małymi dziećmi', 'Pokój dwuosobowy typu Superior z 1 lub 2 łóżkami i widokiem na morze i balkonem', '1 nocleg']}
# 2019-04-10 23:51:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/hr/hotel/split.pl.html>
# {'hotel': 'Hotel Split', 'publish_date': '2015-10-04', 'rev_count': '\n9 opinii\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'W parze']}
# 2019-04-10 23:51:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/hr/hotel/split.pl.html>
# {'hotel': 'Hotel Split', 'publish_date': '2016-05-24', 'rev_count': '\n27 opinii\n', 'rating': '9.6', 'tags': ['Wyjazd wakacyjny', 'W parze']}
# 2019-04-10 23:51:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/hr/hotel/split.pl.html>
# {'hotel': 'Hotel Split', 'publish_date': '2016-04-29', 'rev_count': '\n15 opinii\n', 'rating': '6.7', 'tags': ['Wyjazd wakacyjny', 'W parze']}
# 2019-04-10 23:51:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/hr/hotel/split.pl.html>
# {'hotel': 'Hotel Split', 'publish_date': '2015-11-12', 'rev_count': '\n4 opinie\n', 'rating': '9.6', 'tags': ['Wyjazd służbowy', 'Grupa']}
# 2019-04-10 23:51:23 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.booking.com/hotel/hr/villa-19.pl.html> from <GET https://www.booking.com/hotel/hr/villa-19.pl.html?from=searchresults%0A#hotelTmpl>
# 2019-04-10 23:51:27 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.booking.com/reviews/hr/hotel/apartment-brankica-podstrana.pl.html> (referer: https://www.booking.com/hotel/hr/apartment-brankica-podstrana.pl.html)
# 2019-04-10 23:51:27 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/hr/hotel/apartment-brankica-podstrana.pl.html>
# {'hotel': 'Apartment Brankica', 'publish_date': '2018-07-30', 'rev_count': '\n4 opinie\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'Rodzina z małymi dziećmi', '2 pokoje', '7 noclegów', 'Wysłana przez urządzenie mobilne']}
# 2019-04-10 23:51:27 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/hr/hotel/apartment-brankica-podstrana.pl.html>
# {'hotel': 'Apartment Brankica', 'publish_date': '2017-09-15', 'rev_count': '\n10 opinii\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'Rodzina z małymi dziećmi', 'Apartament – parter', '8 noclegów']}
# 2019-04-10 23:51:27 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/hr/hotel/apartment-brankica-podstrana.pl.html>
# {'hotel': 'Apartment Brankica', 'publish_date': '2017-09-02', 'rev_count': '\n8 opinii\n', 'rating': '9.2', 'tags': ['Wyjazd wakacyjny', 'Rodzina z małymi dziećmi', 'Apartament – parter', '5 noclegów']}
# 2019-04-10 23:51:27 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/hr/hotel/apartment-brankica-podstrana.pl.html>
# {'hotel': 'Apartment Brankica', 'publish_date': '2017-08-14', 'rev_count': '\n4 opinie\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'Rodzina z małymi dziećmi', 'Apartament – parter', '3 noclegi']}
# 2019-04-10 23:51:27 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/hr/hotel/apartment-brankica-podstrana.pl.html>
# {'hotel': 'Apartment Brankica', 'publish_date': '2017-07-18', 'rev_count': '\n5 opinii\n', 'rating': '9.2', 'tags': ['Wyjazd wakacyjny', 'Rodzina z małymi dziećmi', 'Apartament z 3 sypialniami', '11 noclegów']}
# 2019-04-10 23:51:27 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/hr/hotel/apartment-brankica-podstrana.pl.html>
# {'hotel': 'Apartment Brankica', 'publish_date': '2018-08-22', 'rev_count': '\n5 opinii\n', 'rating': '8.8', 'tags': ['Wyjazd wakacyjny', 'Rodzina z małymi dziećmi', 'Apartament z 3 sypialniami', '10 noclegów', 'Wysłana przez urządzenie mobilne']}
# 2019-04-10 23:51:27 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/hr/hotel/apartment-brankica-podstrana.pl.html>
# {'hotel': 'Apartment Brankica', 'publish_date': '2018-07-25', 'rev_count': '\n9 opinii\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'Rodzina z małymi dziećmi', 'Apartament – parter', '10 noclegów']}
# 2019-04-10 23:51:27 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/hr/hotel/apartment-brankica-podstrana.pl.html>
# {'hotel': 'Apartment Brankica', 'publish_date': '2017-08-05', 'rev_count': '\n1 opinia\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'Rodzina z małymi dziećmi', 'Apartament – parter', '7 noclegów']}
# 2019-04-10 23:51:32 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.booking.com/reviews/hr/hotel/apartments-johnny.pl.html> (referer: https://www.booking.com/hotel/hr/apartments-johnny.pl.html)
# 2019-04-10 23:51:32 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/hr/hotel/apartments-johnny.pl.html>
# {'hotel': 'Apartments Johnny', 'publish_date': '2018-07-18', 'rev_count': '\n2 opinie\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Apartament z balkonem i widokiem na morze', '7 noclegów', 'Wysłana przez urządzenie mobilne']}
# 2019-04-10 23:51:32 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/hr/hotel/apartments-johnny.pl.html>
# {'hotel': 'Apartments Johnny', 'publish_date': '2017-09-19', 'rev_count': '\n5 opinii\n', 'rating': '8.8', 'tags': ['Wyjazd wakacyjny', 'Rodzina z małymi dziećmi', 'Apartament z częściowym widokiem na morze (3 osoby dorosłe)', '7 noclegów', 'Wysłana przez urządzenie mobilne']}
# 2019-04-10 23:51:32 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/hr/hotel/apartments-johnny.pl.html>
# {'hotel': 'Apartments Johnny', 'publish_date': '2017-09-07', 'rev_count': '\n19 opinii\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Apartament typu Studio z tarasem i widokiem na morze (2 osoby dorosłe)', '7 noclegów', 'Wysłana przez urządzenie mobilne']}
# 2019-04-10 23:51:32 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/hr/hotel/apartments-johnny.pl.html>
# {'hotel': 'Apartments Johnny', 'publish_date': '2018-08-14', 'rev_count': '\n8 opinii\n', 'rating': '8.3', 'tags': ['Wyjazd wakacyjny', 'Podróżujący ze znajomymi', 'Apartament typu Studio z częściowym widokiem na morze (4 osoby dorosłe)', '2 noclegi', 'Wysłana przez urządzenie mobilne']}
# 2019-04-10 23:51:32 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/hr/hotel/apartments-johnny.pl.html>
# {'hotel': 'Apartments Johnny', 'publish_date': '2018-06-11', 'rev_count': '\n1 opinia\n', 'rating': '8.3', 'tags': ['Wyjazd wakacyjny', 'Grupa', 'Pokój z balkonem i widokiem na morze (2 osoby dorosłe)', '2 noclegi', 'Wysłana przez urządzenie mobilne']}
# 2019-04-10 23:51:32 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/hr/hotel/apartments-johnny.pl.html>
# {'hotel': 'Apartments Johnny', 'publish_date': '2018-05-28', 'rev_count': '\n10 opinii\n', 'rating': '9.2', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój z balkonem i widokiem na morze (2 osoby dorosłe)', '5 noclegów', 'Wysłana przez urządzenie mobilne']}
# 2019-04-10 23:51:32 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/hr/hotel/apartments-johnny.pl.html>
# {'hotel': 'Apartments Johnny', 'publish_date': '2015-08-18', 'rev_count': '\n16 opinii\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'W parze']}
# 2019-04-10 23:51:32 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/hr/hotel/apartments-johnny.pl.html>
# {'hotel': 'Apartments Johnny', 'publish_date': '2015-08-13', 'rev_count': '\n6 opinii\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'Grupa']}
# 2019-04-10 23:51:34 [scrapy.extensions.logstats] INFO: Crawled 26 pages (at 10 pages/min), scraped 66 items (at 66 items/min)
# 2019-04-10 23:51:35 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.booking.com/hotel/hr/apartment-rino.pl.html> from <GET https://www.booking.com/hotel/hr/apartment-rino.pl.html?from=searchresults%0A#hotelTmpl>
# 2019-04-10 23:51:41 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.booking.com/hotel/hr/apartments-mate-podstrana.pl.html> (referer: https://www.booking.com/searchresults.pl.html?dest_id=-92454&dest_type=city&ss=Podstrana&offset=15)
# 2019-04-10 23:51:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.booking.com/searchresults.pl.html?dest_id=-92454&dest_type=city&ss=Podstrana&offset=45> (referer: https://www.booking.com/searchresults.pl.html?dest_id=-92454&dest_type=city&ss=Podstrana&offset=30)
# 2019-04-10 23:51:47 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.booking.com/hotel/hr/the-one-resort.pl.html> from <GET https://www.booking.com/hotel/hr/the-one-resort.pl.html?from=searchresults%0A#hotelTmpl>
# 2019-04-10 23:52:33 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.booking.com/hotel/hr/sanantoniopodstrana.pl.html> (failed 1 times): User timeout caused connection failure: Getting https://www.booking.com/hotel/hr/sanantoniopodstrana.pl.html took longer than 180.0 seconds..
# 2019-04-10 23:52:33 [scrapy.extensions.feedexport] INFO: Stored json feed (66 items) in: hotels.json
# 2019-04-10 23:52:33 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/exception_count': 2,
#  'downloader/exception_type_count/twisted.internet.error.NoRouteError': 1,
#  'downloader/exception_type_count/twisted.internet.error.TimeoutError': 1,
#  'downloader/request_bytes': 30035,
#  'downloader/request_count': 54,
#  'downloader/request_method_count/GET': 54,
#  'downloader/response_bytes': 4185968,
#  'downloader/response_count': 52,
#  'downloader/response_status_count/200': 28,
#  'downloader/response_status_count/301': 24,
#  'dupefilter/filtered': 5,
#  'finish_reason': 'closespider_itemcount',
#  'finish_time': datetime.datetime(2019, 4, 10, 21, 52, 33, 660168),
#  'item_scraped_count': 66,
#  'log_count/DEBUG': 122,
#  'log_count/INFO': 12,
#  'memusage/max': 181645312,
#  'memusage/startup': 74309632,
#  'request_depth_max': 4,
#  'response_received_count': 28,
#  'retry/count': 2,
#  'retry/reason_count/twisted.internet.error.NoRouteError': 1,
#  'retry/reason_count/twisted.internet.error.TimeoutError': 1,
#  'scheduler/dequeued': 54,
#  'scheduler/dequeued/memory': 54,
#  'scheduler/enqueued': 100,
#  'scheduler/enqueued/memory': 100,
#  'start_time': datetime.datetime(2019, 4, 10, 21, 48, 34, 245747)}
# 2019-04-10 23:52:33 [scrapy.core.engine] INFO: Spider closed (closespider_itemcount)

# %%
import pandas as pd;

# %%
df = pd.read_json('hotels.json')

# %%
df['rev_count'] = df['rev_count'].str.strip()
df['rev_count'] = df['rev_count'].str.strip(' opinea')
df['rev_count'] = df['rev_count'].astype(int)

# %%
subdf = df[['rating', 'tags']]

# %%
dum = subdf['tags'].map(lambda tags: '|'.join(tags)).str.get_dummies()

# %%
indicators = pd.concat([subdf['rating'], dum], axis=1)

# %%
melted = pd.melt(indicators, id_vars=['rating'])

# %%
positive = melted['value'] == 1

# %%
selected = melted[positive]

# %%
aggregated = selected.groupby(['variable'])['rating'].agg(['mean', 'count'])

# %%
aggregated.sort_values(by=['count']).tail(10)
# Out:
#                                                      mean  count
# variable
# Pokój Dwuosobowy z balkonem i widokiem na morze  9.100000      5
# Apartament – parter                              9.840000      5
# 6 noclegów                                       9.250000      6
# 2 noclegi                                        7.557143      7
# 7 noclegów                                       9.420000     10
# Grupa                                            8.672727     11
# Wysłana przez urządzenie mobilne                 8.962500     16
# Rodzina z małymi dziećmi                         9.557143     21
# W parze                                          9.013793     29
# Wyjazd wakacyjny                                 9.153226     62
